# %% [markdown]
# # N Queen Attack Detection

# %%
def drawBoard(P):
  N = len(P)
  for i in range(1,N+1):
    print("|", end="")
    for j in range(1,N+1):
      if (i,j) in P:
        ind = str(1+ P.index((i,j)))
        print(" "+ind+" |", end= "")
      else:
        print(" * |", end= "")
    print()

# %%
import math
import random
def generate_positions(N):
    CL = list(range(0,N*N));
    P = []
    for i in range(N):
        p = random.choice(CL)
        CL.remove(p)
        r = ceil((p+1)/N)
        c = 1+p%N
        P.append((r,c))
        print('Q{}: {},{}'.format(i+1,r,c))
    return P

generate_positions(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6732695877f6> in <cell line: 15>()
#      13     return P
#      14
# ---> 15 generate_positions(4)
#
# <ipython-input-6-6732695877f6> in generate_positions(N)
#       7         p = random.choice(CL)
#       8         CL.remove(p)
# ----> 9         r = ceil((p+1)/N)
#      10         c = 1+p%N
#      11         P.append((r,c))
#
# NameError: name 'ceil' is not defined

# %%
generate_positions(4)
# Out:
# Q1: 1,4
# Q2: 1,2
# Q3: 2,4
# Q4: 4,3
# [(1, 4), (1, 2), (2, 4), (4, 3)]

# %%
N = 5
positions = generate_positions(N)
drawBoard(positions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ce2a64137c81> in <cell line: 2>()
#       1 N = 5
# ----> 2 positions = generate_positions(N)
#       3 drawBoard(positions)
#
# NameError: name 'generate_positions' is not defined

# %%
# row attack
def rowAttacK(P):
  count = 0
  for i in range(N):
    for j in range(i+1,N):
      if P[i][0] == P[j][0]:
        print('row attack:', end = " " )
        print(P[i], end = ", ")
        print(P[j])
        count = count + 1
  return count

rowAttacK(positions)
# Out:
# row attack: (1, 5), (1, 3)
# row attack: (5, 3), (5, 4)
# 2

# %%
abs(-2)
# Out:
# 2

# %%
#column attack

# %%
# diagonal atack

# %%
# implement a method to print a state is valid or not
# input row and col (two lists)
def isValid(P):
  #row attack
  #column attack
  #diagonal attack
  return True

# %%
# call isValid untill you get valid solution
